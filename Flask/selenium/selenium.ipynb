# %%
from selenium import webdriver                 
from selenium.webdriver.common.by import By   
from webdriver_manager.chrome import ChromeDriverManager
import time             
from bs4 import BeautifulSoup 
import pandas as pd        
import re

# %% [markdown]
# ## Virginia Laws

# %%
df = pd.read_csv('./virginia_laws.csv')
df['law_text'] = None
df['location'] = 'VA'

# %%
for i in range(len(df)):
    all_content = []
    #get the url - stopped at i = 42
    url = df.loc[i, 'Law']
    driver = webdriver.Chrome()
    #go to url
    driver.get(url)
    try:
        element = driver.find_element(By.CLASS_NAME, "content")
        print('got the element')
        p_elements = element.find_elements(By.TAG_NAME, 'p')
        for p_element in p_elements:
            all_content.append(p_element.text)
        str_content = ''
        for para in all_content:
            str_content = str_content + para
        df.loc[i, 'law_text'] = str_content
    except Exception as e:
        print('data not pulled for', i)
    finally:
        driver.quit()
        print('finished law number: ' , i)

# %%
def clean_text(text):
    return re.sub(r'\s+', ' ', text).strip()
df['law_text'] = df['law_text'].apply(clean_text)
#probably should have done in selenium, but column of the law code name
def get_lawname(text):
    text = text.split('/')[-4:-1]
    law_up = ''
    for i in text:
        output = re.search(r"([a-z]+)([0-9.-]+)", i)
        law_up = law_up + output.group(1) + ' ' + output.group(2) + ' '
    return law_up
df['law_title'] = df['Law'].apply(get_lawname)

# %%
#save to csv
df.to_csv('./virginia_laws.csv', index = False)

# %% [markdown]
# # DC laws

# %%
df_2 = pd.read_csv('./dc_laws.csv')
df_2['law_text'] = None
df_2['location'] = 'DC'

# %%
def using_selenium(df, class_tag, title, tag_name):
    for i in range(len(df)):
        all_content = []
        #get the url - stopped at i = 42
        url = df.loc[i, 'Law']
        driver = webdriver.Chrome()
        #go to url
        driver.get(url)
        try:
            element = driver.find_element(By.CLASS_NAME, class_tag)
            print('got the element')
            title = element.find_element(By.TAG_NAME, title)
            df.loc[i, 'law_title'] = title.text
            print('got the title')
            p_elements = element.find_elements(By.TAG_NAME, tag_name)
            print('got the paragraphs')
            for p_element in p_elements:
                all_content.append(p_element.text)
            str_content = ''
            for para in all_content:
                str_content = str_content + para
            df.loc[i, 'law_text'] = str_content
        except Exception as e:
            print('data not pulled for', i)
        finally:
            driver.quit()
            print('finished law number: ' , i)



# using_selenium(df_2, 'content', 'h1', 'p')

# %%
#save to csv
df_2.to_csv('./dc_laws.csv', index = False)

# %% [markdown]
# ## Maryland Data

# %%
df_3 = pd.read_csv('./maryland_laws.csv')
df_3['law_text'] = None
df_3['law_title'] = None
df_3['location'] = 'MD'

# %%
def using_selenium(df):
    for i in range(len(df)):
        #get the url - stopped at i = 42
        url = df.loc[i, 'Law']
        driver = webdriver.Chrome()
        #go to url
        driver.get(url)
        try:
            element = driver.find_element(By.ID, 'StatuteText')
            df.loc[i, 'law_text'] = element.text
        except Exception as e:
            print('data not pulled for', i)
        finally:
            driver.quit()
            print('finished law number: ' , i)

# %%
using_selenium(df_3)
# Out:
# finished law number:  0
# finished law number:  1
# finished law number:  2
# finished law number:  3
# finished law number:  4
# finished law number:  5
# finished law number:  6
# finished law number:  7
# finished law number:  8
# finished law number:  9
# finished law number:  10
# finished law number:  11
# finished law number:  12
# finished law number:  13
# finished law number:  14
# finished law number:  15
# finished law number:  16
# finished law number:  17
# finished law number:  18
# finished law number:  19
# finished law number:  20
# finished law number:  21
# finished law number:  22
# finished law number:  23
# finished law number:  24
# finished law number:  25
# finished law number:  26
# finished law number:  27
# finished law number:  28
# finished law number:  29
# finished law number:  30
# finished law number:  31
# finished law number:  32
# finished law number:  33
# finished law number:  34
# finished law number:  35
# finished law number:  36
# finished law number:  37
# finished law number:  38
# finished law number:  39
# finished law number:  40
# finished law number:  41
# finished law number:  42
# finished law number:  43
# finished law number:  44
# finished law number:  45
# finished law number:  46
# finished law number:  47
# finished law number:  48
# finished law number:  49
# finished law number:  50
# finished law number:  51
# finished law number:  52
# finished law number:  53
# finished law number:  54
# finished law number:  55
# finished law number:  56
# finished law number:  57
# finished law number:  58
# finished law number:  59
# finished law number:  60
# finished law number:  61
# finished law number:  62
# finished law number:  63
# finished law number:  64
# finished law number:  65
# finished law number:  66
# finished law number:  67
# finished law number:  68
# finished law number:  69
# finished law number:  70
# finished law number:  71
# finished law number:  72
# finished law number:  73
# finished law number:  74
# finished law number:  75
# finished law number:  76
# finished law number:  77
# finished law number:  78
# finished law number:  79
# finished law number:  80
# finished law number:  81
# finished law number:  82
# finished law number:  83
# finished law number:  84
# finished law number:  85
# finished law number:  86
# finished law number:  87
# finished law number:  88
# finished law number:  89
# finished law number:  90
# finished law number:  91
# finished law number:  92
# finished law number:  93
# finished law number:  94
# finished law number:  95
# finished law number:  96
# finished law number:  97
# finished law number:  98
# finished law number:  99
# finished law number:  100
# finished law number:  101
# finished law number:  102
# finished law number:  103
# finished law number:  104
# finished law number:  105
# finished law number:  106
# finished law number:  107
# finished law number:  108
# finished law number:  109
# finished law number:  110
# finished law number:  111
# finished law number:  112
# finished law number:  113
# finished law number:  114
# finished law number:  115
# finished law number:  116
# finished law number:  117
# finished law number:  118
# finished law number:  119
# finished law number:  120
# finished law number:  121
# finished law number:  122
# finished law number:  123
# finished law number:  124
# finished law number:  125
# finished law number:  126
# finished law number:  127
# finished law number:  128
# finished law number:  129
# finished law number:  130
# finished law number:  131
# finished law number:  132
# finished law number:  133
# data not pulled for 134
# finished law number:  134
# finished law number:  135
# finished law number:  136
# finished law number:  137
# finished law number:  138
# finished law number:  139
# finished law number:  140
# finished law number:  141
# finished law number:  142
# finished law number:  143
# finished law number:  144
# finished law number:  145
# finished law number:  146
# finished law number:  147
# finished law number:  148
# finished law number:  149
# finished law number:  150
# finished law number:  151
# finished law number:  152
# finished law number:  153
# finished law number:  154
# finished law number:  155
# finished law number:  156
# finished law number:  157
# finished law number:  158
# finished law number:  159
# finished law number:  160
# finished law number:  161
# finished law number:  162
# finished law number:  163
# finished law number:  164
# finished law number:  165
# finished law number:  166
# finished law number:  167
# finished law number:  168
# finished law number:  169
# finished law number:  170
# finished law number:  171
# finished law number:  172
# finished law number:  173
# finished law number:  174

# %%
text = df_3['law_text'][47]
text = text.replace('\n\n\n', '\n\n')
text = text.split('\n\n')
text
# Out:
# ['Article - Real Property',
#  'Previous\nNext',
#  '§8–304.',
#  '    (a)    When an action of distress is filed, the clerk shall issue an order directing the defendant to appear and show cause at a stated time why levy under an action of distress should not be made. The hearing may be not earlier than seven days from date of service on the defendant.',
#  '    (b)    In addition, the order shall:',
#  '        (1)    Direct the time within which service of the petition and show–cause order shall be made on the defendant; and',
#  '        (2)    Inform the defendant that (i) the defendant may appear at the time stated and present evidence on the defendant’s behalf; and (ii) if the defendant fails to appear, all goods on the leased premises not exempted by law may be levied on and removed by the sheriff.',
#  'Previous\nNext']

# %%
def clean_maryland(text):
    if isinstance(text, str):
        text = text.replace('\n\n\n', '\n\n')
        text = text.split('\n\n')
        
        # Check if text has enough elements
        if len(text) > 3:
            title = text[2].replace('\n§', '').replace('.', '')
            title = f"Article {title}"
            text = text[3].strip()
            return title, text
        else:
            # Handle the case when text does not have enough elements
            return None, None
    else:
        # Handle the case when text is not a string
        return None, None

# Apply the function to the DataFrame
df_3['law_title'], df_3['law_text'] = zip(*df_3['law_text'].apply(clean_maryland))

# %%
df_3[df_3['law_text'].isnull()]
# Out:
#                                                    Law Keywords  Type  \
# 134  https://mgaleg.maryland.gov/mgawebsite/Laws/St...      NaN   NaN
#
#     law_text law_title location
# 134     None      None       MD

# %%
df_3[:135]
# Out:
#                                                    Law  \
# 0    https://mgaleg.maryland.gov/mgawebsite/Laws/St...
# 1    https://mgaleg.maryland.gov/mgawebsite/Laws/St...
# 2    https://mgaleg.maryland.gov/mgawebsite/Laws/St...
# 3    https://mgaleg.maryland.gov/mgawebsite/Laws/St...
# 4    https://mgaleg.maryland.gov/mgawebsite/Laws/St...
# ..                                                 ...
# 130  https://mgaleg.maryland.gov/mgawebsite/Laws/St...
# 131  https://mgaleg.maryland.gov/mgawebsite/Laws/St...
# 132  https://mgaleg.maryland.gov/mgawebsite/Laws/St...
# 133  https://mgaleg.maryland.gov/mgawebsite/Laws/St...
# 134  https://mgaleg.maryland.gov/mgawebsite/Laws/St...
#
#                                               Keywords  Type  \
# 0    Transferee, Reversion, Leased Property, Rent, ...   NaN
# 1                                                  NaN   NaN
# 2                                                  NaN   NaN
# 3                                                  NaN   NaN
# 4                                                  NaN   NaN
# ..                                                 ...   ...
# 130                                                NaN   NaN
# 131                                                NaN   NaN
# 132                                                NaN   NaN
# 133                                                NaN   NaN
# 134                                                NaN   NaN
#
#                                               law_text        law_title  \
# 0    A transferee of the reversion in leased proper...   Article §8–101
# 1    If the reversion of any leased premises merges...   Article §8–102
# 2    There is no merger by reason of any grant by w...   Article §8–103
# 3    Any grant of a nonpossessory corporeal estate ...   Article §8–104
# 4    If the effect of any provision of a lease is t...   Article §8–105
# ..                                                 ...              ...
# 130  (a)    A park owner shall offer all current an...  Article §8A–202
# 131  (a)    (1)    A park owner shall establish rea...  Article §8A–301
# 132  (a)    A park owner may increase a park fee on...  Article §8A–401
# 133      (a)    An entrance or exit fee is prohibited.  Article §8A–402
# 134                                               None             None
#
#     location
# 0         MD
# 1         MD
# 2         MD
# 3         MD
# 4         MD
# ..       ...
# 130       MD
# 131       MD
# 132       MD
# 133       MD
# 134       MD
#
# [135 rows x 6 columns]

# %%
df_3.loc[134,'law_title'] = 'Article §8-403'
df_3.loc[134,'law_text'] = '(a)    A park owner may charge the resident a reasonable service fee, based on an amount that the park owner directly incurs, for installing, placing on, or removing a mobile home from the site. (b)    In each case where a fee has been charged by a park owner, a written description detailing the fee shall be provided by the park owner to the resident.'

# %%
df_3[df_3['law_text'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Law, Keywords, Type, law_text, law_title, location]
# Index: []

# %%
df_3.to_csv('./maryland_laws.csv', index = False)
