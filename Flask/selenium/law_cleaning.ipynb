# %%
import pandas as pd
import re 
df_va = pd.read_csv('virginia_laws.csv')
df_va = df_va[:-1]
df_dc = pd.read_csv('dc_laws.csv')
df_md = pd.read_csv('maryland_laws.csv')

# %%
#characters to remove
#A. B. C. (any charcter followed by a period) regex > [A-Z]\.
#§ 
combined_pattern = re.compile(r'[A-Z1-9]\.|\([a-z1-9]\)|\(i*\)|\(u[*]')
section_pattern = re.compile('§')
df_va['law_text'] = df_va['law_text'].apply(lambda x: combined_pattern.sub("", x))
df_md['law_text'] = df_md['law_text'].apply(lambda x: combined_pattern.sub("", x))
df_dc['law_text'] = df_dc['law_text'].apply(lambda x: combined_pattern.sub("", x))

df_va['law_text'] = df_va['law_text'].apply(lambda x: section_pattern.sub("Section", x))
df_md['law_text'] = df_md['law_text'].apply(lambda x: section_pattern.sub("Section", x))
df_dc['law_text'] = df_dc['law_text'].apply(lambda x: section_pattern.sub("Section", x))

# %% [markdown]
# ## creating the final dataframe

# %%
df_va_subset = df_va[['law_title', 'law_text', 'location', 'Type', 'Keywords']]
df_md_subset = df_md[['law_title', 'law_text', 'location', 'Type', 'Keywords']]
df_dc_subset = df_dc[['law_title', 'law_text', 'location', 'Type', 'Keywords']]
df_final = pd.concat([df_va_subset, df_md_subset, df_dc_subset])
df_final
# Out:
#                                             law_title  \
# 0            title 55.1 chapter 12 section 55.1-1203
# 1            title 55.1 chapter 12 section 55.1-1204
# 2            title 55.1 chapter 12 section 55.1-1205
# 3            title 55.1 chapter 12 section 55.1-1206
# 4            title 55.1 chapter 12 section 55.1-1207
# ..                                                ...
# 28  § 42–3228. Lease held by an infant or person w...
# 29  § 42–3229. Surrender for new lease good withou...
# 30  § 42–3230. Grant or assignment of reversion of...
# 31  § 42–3231. Grants of remainders, reversions, a...
# 32  § 42–3232. Fraudulent attornment void; possess...
#
#                                              law_text location  \
# 0    Any landlord may require a refundable applica...       VA
# 1    A landlord and tenant may include in a rental...       VA
# 2   A landlord and a tenant may agree in a rental ...       VA
# 3    A landlord may require as a condition of tena...       VA
# 4   If the landlord does not sign and deliver a wr...       VA
# ..                                                ...      ...
# 28  Every such surrender, and such lease or leases...       DC
# 29  In case any lease shall be duly surrendered, i...       DC
# 30  The grantee or assignee of the reversion of an...       DC
# 31  All grants or conveyances of any manors or ren...       DC
# 32  All and every fraudulent attornment and attorn...       DC
#
#                   Type                                           Keywords
# 0   General Provisions  application, deposit, identification, ID, cred...
# 1   General Provisions  rent, payment, security deposit, receipt, agre...
# 2   General Provisions                                       prepaid rent
# 3   General Provisions            insurance, renter's insurance, coverage
# 4   General Provisions                          agreement, unsigned, rent
# ..                 ...                                                ...
# 28                 NaN  Lease, Infant, Mental disability, Renewed leas...
# 29                 NaN  Surrender, New lease, Underleases, Chief landl...
# 30                 NaN  Grant, Assignment, Reversion, Premises, Lessee...
# 31                 NaN  Grants, Remainders, Reversions, Rents, Attornm...
# 32                 NaN  Fraudulent, Attornment, Void, Possession, Tena...
#
# [255 rows x 5 columns]

# %%
df_final['law_title'] = df_final['law_title'].apply(lambda x: section_pattern.sub("Section", x))

# %%
df_final.to_csv('./clean_data.csv', index = False)
